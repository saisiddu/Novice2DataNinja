# %% [markdown]
# #### Lesson Objective:
# * learn how to read and play sound files in a Jupyter notebook
# * learn how to create a spectrogram from a signal
# * learn how to compare two signals

# %% [markdown]
# #### Reading and Playing Sound

# %%
# import common packages
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# For this tutorial we will use a [dataset](https://zenodo.org/record/574438#.WVyQatPyvzI) extracted from the [xeno-canto](http://www.xeno-canto.org/) database of bird recordings.

# %% [markdown]
# The recordings are in `.wav` format. We can use the `io` submodule of `scipy` to read them.

# %%
from scipy.io import wavfile

# %%
birdsound = wavfile.read('data/PicidaeDataset/DendrocoposMedius-song/XC26678-DendrocoposMedius-song-1.wav')
birdsound2 = wavfile.read('data/PicidaeDataset/DendrocoposMedius-song/XC26678-DendrocoposMedius-song-2.wav')

# %%
plt.plot(birdsound[1])
plt.plot(birdsound2[1])

# %% [markdown]
# The output object is a tuple of a frequency and a 1D signal (it is possible that the recording contains more than one channels, and then we have a 2D array)

# %%
# structure of the sound object
str(birdsound)
# Out:
# '(44100, array([2351, 4447, 6454, ...,  150,  379,  442], dtype=int16))'

# %% [markdown]
# Plotting the signal:
#
# to obtain the time axis in seconds we need to divide the frame number by the frequency.

# %%
plt.plot(np.linspace(0,len(birdsound[1])/birdsound[0], len(birdsound[1])),birdsound[1])
plt.xlabel('Time in s')

# %% [markdown]
# We can play the sound directly in the Jupyter notebook:

# %%
from IPython.display import Audio

# %%
Audio('data/PicidaeDataset/DendrocoposMedius-song/XC26678-DendrocoposMedius-song-1.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Spectrogram

# %% [markdown]
# It is useful to look at the spectrogram of the signal as it shows details at different frequencies.

# %% [markdown]
# This can be achieved through the `specgram` function in `matplotlib`.

# %%
Pxx, freqs, bins, im = plt.specgram(birdsound[1],Fs = birdsound[0])
plt.title('Song Spectrogram')

# %% [markdown]
# In general there are different approaches working with sound:
#
# * working with the signal directly
# * working with the spectrogram
# * working with features extracted from the singal/spectrogram

# %% [markdown]
# In order to automate the process of reading files, we can use the `glob` function, which gives us all filenames in a given directory.

# %%
from glob import glob

# %%
filenames = glob('data/PicidaeDataset/DendrocoposMinor-drumming/*')

# %%
filenames
# Out:
# ['data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234155-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234155-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-12.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-13.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-14.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-15.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-16.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-17.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-18.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-19.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-20.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-12.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-13.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-14.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-15.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-16.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-17.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-12.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-13.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-14.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-15.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-16.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-17.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-18.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-19.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-20.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-21.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-22.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-23.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-24.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-25.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC277517-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC277517-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC277517-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC314610-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC314610-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC343686-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC343686-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC343686-DendrocoposMinor-drumming-3.wav']

# %% [markdown]
# The filenames may not be ordered, but we can order them for consistency:

# %%
filenames = sorted(filenames)
filenames
# Out:
# ['data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC221271-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234155-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234155-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-12.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-13.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-14.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-15.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-16.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-17.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-18.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-19.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-20.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC234544-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-12.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-13.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-14.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-15.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-16.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-17.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236456-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236458-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-10.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-11.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-12.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-13.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-14.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-15.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-16.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-17.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-18.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-19.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-20.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-21.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-22.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-23.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-24.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-25.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236460-DendrocoposMinor-drumming-9.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC236833-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC239446-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC277517-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC277517-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC277517-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC309580-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC312823-DendrocoposMinor-drumming-8.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC314610-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC314610-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC329937-DendrocoposMinor-drumming-7.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-3.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-4.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-5.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC337994-DendrocoposMinor-drumming-6.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC343686-DendrocoposMinor-drumming-1.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC343686-DendrocoposMinor-drumming-2.wav',
#  'data/PicidaeDataset/DendrocoposMinor-drumming\\XC343686-DendrocoposMinor-drumming-3.wav']

# %%
songs = [wavfile.read(file) for file in filenames]

# %%
plt.figure(figsize = [10,5])
plt.plot(songs[0][1])
plt.plot(songs[1][1],'r')

# %% [markdown]
# To compare two different drummings we need to first align them. We can achieve that by moving one of the signals to be maximally correlated with the other one.

# %% [markdown]
# We can efficiently calculate cross-correlation using Fast Fourier Transforms:

# %%
from scipy import signal

# %%
cc = signal.fftconvolve(np.abs(songs[0][1]),np.abs(songs[1][1][::-1]), mode='full')
l  = len(songs[1][1])

# finding the offset of maximum correlation
offset = cc.argmax() + l  - len(cc)
offset
# Out:
# -9582

# %%
# shift signal 1 by the ofset to align with signal 2
plt.plot(songs[0][1][-offset:])
plt.plot(songs[1][1],'r')

# %% [markdown]
# Exercise:
#
# * define a similarity measure between two bird sounds
# * calculate the similarity for every pair of two sounds
# * build a network of bird sounds and explore its connectivity
# * mix sounds from different birds: does your similarity separate the different species?
